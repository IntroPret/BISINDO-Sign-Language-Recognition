# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import shutil
import cv2
import pandas as pd
from tqdm import tqdm
from sklearn.model_selection import train_test_split

# %%
# Dataset
dataset_path = '/content/drive/MyDrive/bisindo_dataset'

# Target
output_path = '/content/drive/MyDrive/bisindo_dataset_split'
train_path = os.path.join(output_path, 'train')
val_path = os.path.join(output_path, 'val')
test_path = os.path.join(output_path, 'test')

# %%
# Create output directories
for folder in [train_path, val_path, test_path]:
    os.makedirs(folder, exist_ok=True)

# %%
data = []
for label in os.listdir(dataset_path):
    class_dir = os.path.join(dataset_path, label)
    if not os.path.isdir(class_dir):
        continue
    for fname in os.listdir(class_dir):
        if fname.lower().endswith(('.jpg', '.jpeg', '.png')):
            filepath = os.path.join(class_dir, fname)
            data.append((filepath, label))

# %%
df = pd.DataFrame(data, columns=['filepath', 'label'])

# %%
# Step 2: Stratified split
train_df, temp_df = train_test_split(df, test_size=0.3, stratify=df['label'], random_state=1)
val_df, test_df = train_test_split(temp_df, test_size=0.5, stratify=temp_df['label'], random_state=1)

# %%
# Step 3: Copy function
def copy_files(df, target_dir):
    for _, row in tqdm(df.iterrows(), total=len(df), desc=f'Copying to {os.path.basename(target_dir)}'):
        label_dir = os.path.join(target_dir, row['label'])
        os.makedirs(label_dir, exist_ok=True)
        dst_path = os.path.join(label_dir, os.path.basename(row['filepath']))
        shutil.copy2(row['filepath'], dst_path)

# %%
# Step 4: Perform copy
copy_files(train_df, train_path)
copy_files(val_df, val_path)
copy_files(test_df, test_path)

print("\nStratified split complete: train/val/test saved in:", output_path)
# Out:
# Copying to train: 100%|██████████| 3126/3126 [35:40<00:00,  1.46it/s]
# Copying to val: 100%|██████████| 670/670 [07:40<00:00,  1.46it/s]
# Copying to test: 100%|██████████| 670/670 [07:53<00:00,  1.42it/s]
# Stratified split complete: train/val/test saved in: /content/drive/MyDrive/bisindo_dataset_split

# %%
# Check the Dataset Again
def analyze_dataset(dataset_path):
    class_data = []
    image_shapes = set()
    total_images = 0
    inaccessible_images_total = 0
    inconsistent_shapes = False

    for label in sorted(os.listdir(dataset_path)):
        label_path = os.path.join(dataset_path, label)
        if not os.path.isdir(label_path):
            continue

        image_files = [
            f for f in os.listdir(label_path)
            if f.lower().endswith(('.jpg', '.jpeg', '.png'))
        ]
        count = len(image_files)
        total_images += count

        # Get sample image names
        sample_files = ", ".join(image_files[:3]) if image_files else "-"

        # Check shape from first few images
        local_shapes = set()
        for img_file in image_files[:5]:
            img_path = os.path.join(label_path, img_file)
            img = cv2.imread(img_path)
            if img is not None:
                local_shapes.add(img.shape)
                image_shapes.add(img.shape)

        # Record potential shape inconsistency
        if len(local_shapes) > 1:
            inconsistent_shapes = True

        class_data.append({
            "Label": label,
            "Number of Images": count,
            "Sample Filenames": sample_files,
            "Detected Shapes": list(local_shapes)
        })

    # Convert to DataFrame
    df = pd.DataFrame(class_data)
    df = df.sort_values("Label").reset_index(drop=True)

    # Display table
    print(f"Total Classes: {len(df)}")
    print(f"Total Images: {total_images}")
    if inconsistent_shapes or len(image_shapes) > 1:
        print("Warning: Multiple image resolutions detected.")

    return df

# %%
# Train
train_df = analyze_dataset(train_path)
train_df
# Out:
# Total Classes: 26
# Total Images: 3126
# Warning: Multiple image resolutions detected.
#    Label  Number of Images                                   Sample Filenames  \
# 0      A               116  A_Background Baju_Samsung_A55.jpg, A_Polos Ter...
# 1      B               118  B_BACKGROUNDBAJU_VIVO_V20.jpeg, B_Polos terang...
# 2      C               118  C_Polos Gelap_Samsung_A55.jpg, C_Polos Gelap_O...
# 16  [(3024, 3024, 3), (720, 720, 3), (3456, 3456, 3)]
# 17  [(2544, 2544, 3), (4000, 4000, 3), (3056, 3056...
# 18  [(1280, 1280, 3), (3056, 3056, 3), (1427, 1500...
# 19  [(2316, 2316, 3), (3072, 3072, 3), (4000, 4000...
# 20  [(1280, 1280, 3), (3024, 3024, 3), (3456, 3456...
# 21  [(2544, 2544, 3), (2316, 2316, 3), (3024, 3024...
# 22  [(2992, 2992, 3), (2316, 2316, 3), (3024, 3024...
# 23  [(3072, 3072, 3), (1435, 1435, 3), (3056, 3056...
# 24  [(1022, 1022, 3), (3024, 3024, 3), (3072, 3072...
# 25  [(2992, 2992, 3), (3948, 3948, 3), (3072, 3072...

# %%
# Val
val_df = analyze_dataset(val_path)
val_df
# Out:
# Total Classes: 26
# Total Images: 670
# Warning: Multiple image resolutions detected.
#    Label  Number of Images                                   Sample Filenames  \
# 0      A                25  A_Polos Terang_Samsung_A21S.jpeg, A_Bebas_Sams...
# 1      B                25  B_Polos Terang_ROG_Phone5.jpg, B_Baju_Apple_Ip...
# 2      C                25  C_backgroundputih_vivov20.jpeg, C_BAJU PUTIH_S...
# 3      D                26  D_Polos Gelap_Samsung_Galaxy A32 5G.jpg, 20240...
# 4      E                25  E_Polos Terang_iPhone_XR.jpeg, E_Body Red_Xiao...
# 5      F                26  F_background baju_Samsung_A33.jpg, 20240509_18...
# 6      G                26  G_Polos Gelap_Vivo_V23 5G.jpg, G_backgroundhit...
# 7      H                26  H_Bebas_Samsung_Galaxy M14 5G.jpg, H_Polos Ter...
# 8      I                26  I_Batik_Sony_A7C.JPG, I_Baju_Infinix_Hot 11s N...
# 9      J                25  J_Polos Terang_Redmi_Note 12 Pro.jpg, J_Putih_...
# 10     K                26  K_Background_Polos_Terang_POCO_F4.jpg, K_Polos...
# 11     L                25  L_Baju_Xiaomi_Redmi Note 11.jpg, L_bebas_Iph_I...
# 12     M                26  M_Hitam Polos_Vivo_V21.jpg, M_Bebas_Samsung_M5...
# 13     N                26  N_Baju_Redmi_Note 12 Pro.jpg, N_Polos terang_I...
# 14     O                26  O_Polos Gelap_Apple_Iphone 15.jpg, O_Bebas_Opp...
# 15     P                26  P_Bebas_iPhone_14 Pro (2).jpg, P_polos gelap_I...
# 16     Q                26  Q_Bebas_Samsung_A23.jpeg, Q_Polos Gelap_Vivo_V...
# 17     R                26  R_Polos Terang_Redmi_Note 12 Pro.jpg, R_Polos ...
# 18     S                26  S_Baju_iPhone_14 Pro (2).jpg, S_Polos Gelap_Xi...
# 19     T                26  T_Polos Terang_Samsung_A22.jpg, T_Baju_Redmi_9...
# 20     U                26  U_Bebas_iPhone_14 Pro.jpg, U_Polos Gelap_Samsu...
# 21     V                26  V_Polos Terang_Redmi_9 Pro.jpg, V_Background B...
# 22     W                26  W_Baju_Samsung_A22.jpg, W_Bebas_Infinix_Hot 11...
# 23     X                26  X_Bebas_ROG_Phone5.jpg, X_Polos Terang_Samsung...
# 24     Y                26  Y_Bebas_Xiaomi_Redmi Note 11.jpg, Y_Polos Tera...
# 25     Z                26  Z_Polos Terang_Redmi_Note 12 Pro.jpg, Z_backgo...
#
#                                       Detected Shapes
# 0   [(2448, 2448, 3), (4224, 4224, 3), (667, 668, ...
# 1   [(3072, 3072, 3), (2316, 2316, 3), (3056, 3056...
# 2   [(1280, 1280, 3), (3024, 3024, 3), (4000, 4000...
# 3   [(2992, 2992, 3), (2316, 2316, 3), (3056, 3056...
# 4   [(1600, 1600, 3), (2992, 2992, 3), (3472, 3472...
# 5   [(1388, 1388, 3), (2544, 2544, 3), (3056, 3056...
# 6   [(1280, 1280, 3), (3024, 3024, 3), (3464, 3464...
# 7   [(1280, 1280, 3), (2316, 2316, 3), (3024, 3024...
# 8   [(1280, 1280, 3), (1581, 1581, 3), (2944, 2944...
# 9   [(2544, 2544, 3), (2944, 2944, 3), (3072, 3072...
# 10  [(2944, 2944, 3), (3072, 3072, 3), (3473, 3472...
# 11  [(2448, 2448, 3), (3072, 3072, 3), (3472, 3472...
# 12  [(1280, 1280, 3), (2992, 2992, 3), (2448, 2448...
# 13  [(2944, 2944, 3), (3072, 3072, 3), (3456, 3456...
# 14  [(1572, 1572, 3), (3056, 3056, 3), (1498, 1497...
# 15  [(2992, 2992, 3), (4000, 4000, 3), (3456, 3456...
# 16  [(1280, 1280, 3), (2316, 2316, 3), (575, 576, ...
# 17  [(2448, 2448, 3), (3024, 3024, 3), (3072, 3072...
# 18  [(976, 976, 3), (2316, 2316, 3), (3072, 3072, ...
# 19  [(2992, 2992, 3), (3472, 3472, 3), (2938, 2938...
# 20  [(3472, 3472, 3), (3456, 3456, 3), (1013, 1013...
# 21  [(3472, 3472, 3), (3056, 3056, 3), (3456, 3456...
# 22  [(2544, 2544, 3), (2992, 2992, 3), (2316, 2316...
# 23  [(2992, 2992, 3), (2316, 2316, 3), (3456, 3456...
# 24  [(3072, 3072, 3), (2992, 2992, 3), (568, 568, ...
# 25  [(3072, 3072, 3), (2448, 2448, 3), (1499, 1499...

# %%
# Test
test_df = analyze_dataset(test_path)
test_df
# Out:
# Total Classes: 26
# Total Images: 670
# Warning: Multiple image resolutions detected.
#    Label  Number of Images                                   Sample Filenames  \
# 0      A                24  A_Baju_Samsung_A22.jpg, A_Bebas_Oppo_A53.jpg, ...
# 1      B                26  B_Baju_Vivo_V21.jpg, B_POLOS GELAP_SAMSUNG_S22...
# 2      C                26  C_Bebas_Apple_Iphone XS.jpg, C_Background Polo...
# 3      D                25  D_Polos Terang_Infinix_Hot 11s NFC.jpg, IMG_20...
# 4      E                26  E_Background_Polos_Terang_POCO_F4.jpg, E_Bebas...
# 5      F                26  F_Background Baju_Samsung_A55.jpg, F_Baju_Appl...
# 6      G                26  G_Bebas_Samsung_A32.jpg, G_BAJU_Apple_Iphone 1...
# 7      H                26  H_Bebas_ROG_Phone5.jpg, H_Background_Baju_POCO...
# 8      I                26  I_Background Baju_Iphone 14 Pro.jpg, I_Bebas_S...
# 9      J                26  J_Polos terang_Oppo_A53.jpg, J_Bebas_Xiaomi _N...
# 10     K                26  K_Polos Gelap_Samsung_Galaxy M14 5G.jpg, K_Bod...
# 11     L                26  L_Bebas_Vivo_V23 5G.jpg, L_Baju_Sony_A7C.JPG, ...
# 12     M                26  M_Wall Gray_Xiaomi_Redmi Note 9.jpg, M_Baju Hi...
# 13     N                26  N_background baju_Samsung_A33.jpg, N_Backgroun...
# 14     O                26  O_Bebas_Samsung_A23.jpeg, O_Polos Terang_Redmi...
# 15     P                26  P_Bebas_Iphone_14 Pro.jpg, P_Background _Bebas...
# 16     Q                26  Q_Baju_Realme_7i.jpg, Q_Polos Terang_Realme_7i...
# 17     R                25  R_Background_Polos_Terang_POCO_F4.jpg, R_Gelap...
# 18     S                26  S_PolosGelap_Xiaomi_Poco X3.jpg, 20240509_1856...
# 19     T                26  T_Baju_Iphone_14Pro.jpg, T_Hitam_Samsung_M51.j...
# 20     U                26  U_Baju_Samsung_A23.jpeg, U_Background_Polos_Te...
# 21     V                25  V_polos gelap_Iphone_13promax.jpg, V_Polos Ter...
# 22     W                25  W_Baju_iPhone_XR.jpeg, W_PolosTerang_Xiaomi_Po...
# 23     X                26  X_polos gelap_Iphone_13promax.jpg, X_Bebas_Opp...
# 24     Y                26  Y_Baju_Samsung_A51.jpg, Y_Bebas_Iphone_14 Pro....
# 25     Z                26  Z_Polos Terang_ROG_Phone5.jpg, Z_Background_Be...
#
#                                       Detected Shapes
# 0   [(2992, 2992, 3), (3024, 3024, 3), (2944, 2944...
# 1   [(1280, 1280, 3), (2992, 2992, 3), (3456, 3456...
# 2   [(2448, 2448, 3), (720, 720, 3), (2180, 2180, ...
# 3   [(1280, 1280, 3), (1282, 1284, 3), (2944, 2944...
# 4   [(1280, 1280, 3), (2992, 2992, 3), (3472, 3472...
# 5   [(1280, 1280, 3), (720, 720, 3), (3056, 3056, ...
# 6   [(2316, 2316, 3), (3024, 3024, 3), (3456, 3456...
# 7   [(3904, 3904, 3), (3056, 3056, 3), (1600, 1600...
# 8   [(2992, 2992, 3), (3024, 3024, 3), (2604, 2753...
# 9   [(3024, 3024, 3), (1280, 1280, 3), (2992, 2992...
# 10  [(2992, 2992, 3), (2316, 2316, 3), (3056, 3056...
# 11  [(3000, 3000, 3), (4000, 4000, 3), (3456, 3456...
# 12  [(1836, 1836, 3), (2992, 2992, 3), (3456, 3456...
# 13  [(2992, 2992, 3), (2544, 2544, 3), (3024, 3024...
# 14  [(3024, 3024, 3), (3072, 3072, 3), (1528, 1528...
# 15  [(3024, 3024, 3), (3472, 3472, 3), (3056, 3056...
# 16  [(3072, 3072, 3), (2992, 2992, 3), (1280, 1280...
# 17  [(1280, 1280, 3), (720, 720, 3), (3456, 3456, ...
# 18  [(3024, 3024, 3), (1392, 1392, 3), (3056, 3056...
# 19  [(2448, 2448, 3), (3072, 3072, 3), (3456, 3456...
# 20  [(3024, 3024, 3), (1528, 1528, 3), (3472, 3472...
# 21  [(1280, 1280, 3), (3072, 3072, 3), (1472, 1472...
# 22  [(3456, 3456, 3), (1600, 1600, 3), (3072, 3072...
# 23  [(3024, 3024, 3), (2944, 2944, 3), (1551, 1500...
# 24  [(2448, 2448, 3), (3024, 3024, 3), (2033, 2033...
# 25  [(1254, 1254, 3), (1280, 1280, 3), (3472, 3472...
